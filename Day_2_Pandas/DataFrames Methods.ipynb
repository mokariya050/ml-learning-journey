# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ipl=pd.read_csv('ipl-matches.csv')
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts().head(3)
# Out:
# Player_of_Match
# F du Plessis    3
# SK Raina        3
# KA Pollard      3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
ipl['TossDecision'].value_counts().plot(kind='pie',autopct="%1.1f%%",colors=['red','blue'])
plt.show()

# %%
(ipl['Team1'].value_counts()+ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.sort_values(by=['title_x'],na_position='first').head(2)
# Out:
#                  title_x    imdb_id  \
# 1498  16 December (film)  tt0313844
# 1021         1920 (film)  tt1301698
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link title_y original_title  \
# 1498  https://en.wikipedia.org/wiki/16_December_(film)  16-Dec         16-Dec
# 1021         https://en.wikipedia.org/wiki/1920_(film)    1920           1920
#
#       is_adult  year_of_release runtime                  genres  imdb_rating  \
# 1498         0             2002     158         Action|Thriller          6.9
# 1021         0             2008     138  Horror|Mystery|Romance          6.4
#
#       imdb_votes                                              story  \
# 1498        1091  16 December  1971 was the day when India won t...
# 1021        2588  A devotee of Bhagwan Shri Hanuman  Arjun Singh...
#
# ...

# %%
# rank method (Series)
batsman=pd.read_csv("batsman_runs_ipl.csv")
batsman.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
batsman['batsman_rank']=batsman['batsman_run'].rank(ascending=False)

# %%
batsman.head()
# Out:
#            batter  batsman_run  batsman_rank
# 0  A Ashish Reddy          280         166.5
# 1        A Badoni          161         226.0
# 2      A Chandila            4         535.0
# 3        A Chopra           53         329.0
# 4     A Choudhary           25         402.5

# %%
# sort_index also available
batsman.sort_values(by=['batsman_rank'])
# Out:
#              batter  batsman_run  batsman_rank
# 569         V Kohli         6634           1.0
# 462        S Dhawan         6244           2.0
# 130       DA Warner         5883           3.0
# 430       RG Sharma         5881           4.0
# 493        SK Raina         5536           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh            0         594.0
# 63     Abdur Razzak            0         594.0
# 562          U Kaul            0         594.0
# 65       Akash Deep            0         594.0
# 57           AS Roy            0         594.0
#
# [605 rows x 3 columns]

# %%
movies.sort_index(ascending=False).head(4)
# Out:
#                    title_x     imdb_id  \
# 1628              Humsafar   tt2403201
# 1627                 Daaka  tt10833860
# 1626       Sabse Bada Sukh   tt0069204
# 1625  Yeh Zindagi Ka Safar   tt0298607
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link               title_y  \
# 1628             https://en.wikipedia.org/wiki/Humsafar              Humsafar
# 1627                https://en.wikipedia.org/wiki/Daaka                 Daaka
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh       Sabse Bada Sukh
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...  Yeh Zindagi Ka Safar
#
#             original_title  is_adult  year_of_release runtime         genres  \
# ...

# %%
batsman.set_index('batter',drop=False,inplace=True)
batsman.index.name=None

# %%
batsman.head()
# Out:
#                         batter  batsman_run  batsman_rank
# A Ashish Reddy  A Ashish Reddy          280         166.5
# A Badoni              A Badoni          161         226.0
# A Chandila          A Chandila            4         535.0
# A Chopra              A Chopra           53         329.0
# A Choudhary        A Choudhary           25         402.5

# %%
batsman.reset_index(drop=True,inplace=True)
batsman.head()
# Out:
#            batter  batsman_run  batsman_rank
# 0  A Ashish Reddy          280         166.5
# 1        A Badoni          161         226.0
# 2      A Chandila            4         535.0
# 3        A Chopra           53         329.0
# 4     A Choudhary           25         402.5

# %%
name=batsman['batter'].reset_index(drop=False)
name.head()
# Out:
#    index          batter
# 0      0  A Ashish Reddy
# 1      1        A Badoni
# 2      2      A Chandila
# 3      3        A Chopra
# 4      4     A Choudhary

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies.rename(columns={'title_x':'title','imdb_id':'id'}).head(1)
# Out:
#                       title         id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movies.set_index('title_x',inplace=True)

# %%
movies.rename(index={'Uri: The Surgical Strike':'Uri','Battalion 609':'Battalion'}).head(2)
# Out:
#              imdb_id                                        poster_path  \
# title_x
# Uri        tt8291224  https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion  tt9472208                                                NaN
#
#                                                    wiki_link  \
# title_x
# Uri        https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# Battalion        https://en.wikipedia.org/wiki/Battalion_609
#
#                             title_y            original_title  is_adult  \
# title_x
# Uri        Uri: The Surgical Strike  Uri: The Surgical Strike         0
# Battalion             Battalion 609             Battalion 609         0
#
#            year_of_release runtime            genres  imdb_rating  imdb_votes  \
# title_x
# Uri                   2019     138  Action|Drama|War          8.4       35112
# Battalion             2019     131               War          4.1          73
#
#                                                        story  \
# ...

# %%
# unique
a=[1,1,2,3,4,55,55,np.nan]
s=pd.Series(a)
s.unique()
# Out:
# array([ 1,  2,  3,  4, 55,  6])

# %%
ipl['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
# nunique
a=[1,1,2,3,4,55,55,np.nan]
s=pd.Series(a)
s.nunique()
# Out:
# 5

# %%
# data frame and series have not null value than return true
batsman.notnull().sum()
# Out:
# batter          605
# batsman_run     605
# batsman_rank    605
# dtype: int64

# %%
# if series have atleast one missing value than return True else False
s.hasnans
# Out:
# 1

# %%
# parameter -> axis,how,thres -> minimum number of nan values,subset
# if thres=2 than keep raw if at least 2 missing value
s.dropna()
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     3.0
# 4     4.0
# 5    55.0
# 6    55.0
# dtype: float64

# %%
# fillna parameter -> value,method -> 'ffill',limit -> number of replacement
# you can also pass a dict than fill column wise values
s.fillna(method='bfill')
# Out:
# C:\Users\PRASHANT\AppData\Local\Temp\ipykernel_6928\923200219.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s.fillna(method='bfill')
# 0     1.0
# 1     1.0
# 2     2.0
# 3     3.0
# 4     4.0
# 5    55.0
# 6    55.0
# 7     NaN
# dtype: float64

# %%
batsman.duplicated().sum()
# Out:
# np.int64(0)

# %%
s.duplicated().sum()
# Out:
# np.int64(2)

# %%
# remove duplicates value from data set
s.drop_duplicates(keep='last',ignore_index=True)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4    55.0
# 5     NaN
# dtype: float64

# %%
# find out the last match play by virat kohli in delhi
ipl[
    (ipl['City'] == 'Delhi') &
    (
        ipl['Team1Players'].str.contains('V Kohli') |
        ipl['Team2Players'].str.contains('V Kohli')
    )
].sort_values(by=['Season']).drop_duplicates(subset=['City'],keep='last')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision SuperOver     WinningTeam WonBy  Margin method  \
# 208          bat         N  Delhi Capitals  Runs    16.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 208        S Dhawan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2
# 208  KN Ananthapadmanabhan

# %%
# remove rows and columns from data set
batsman.drop(index=[1,4]).head(5)
# Out:
#            batter  batsman_run  batsman_rank
# 0  A Ashish Reddy          280         166.5
# 2      A Chandila            4         535.0
# 3        A Chopra           53         329.0
# 5     A Dananjaya            4         535.0
# 6      A Flintoff           62         319.0

# %%
batsman.set_index('batter').drop(index=['A Ashish Reddy'],inplace=True)

# %%
batsman.head()
# Out:
#            batter  batsman_run  batsman_rank
# 0  A Ashish Reddy          280         166.5
# 1        A Badoni          161         226.0
# 2      A Chandila            4         535.0
# 3        A Chopra           53         329.0
# 4     A Choudhary           25         402.5

# %%
batsman['batsman_run'].apply(lambda x:x+2)
# Out:
# 0       282
# 1       163
# 2         6
# 3        55
# 4        27
#        ...
# 600       2
# 601      49
# 602       5
# 603    2756
# 604     119
# Name: batsman_run, Length: 605, dtype: int64
