# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# create series

contry=['India','Pakistan','Nepal','Bhutan','Srilanka']
pd.Series(contry)
# Out:
# 0       India
# 1    Pakistan
# 2       Nepal
# 3      Bhutan
# 4    Srilanka
# dtype: object

# %%
runs=[12,20,40,44,100]
pd.Series(runs)
# Out:
# 0     12
# 1     20
# 2     40
# 3     44
# 4    100
# dtype: int64

# %%
# custom index
marks=[70,80,90,77,50]
sub=['chemestry','physics','maths','computer','english']
pd.Series(data=marks,index=sub)
# Out:
# chemestry    70
# physics      80
# maths        90
# computer     77
# english      50
# dtype: int64

# %%
# name
marks=[70,80,90,77,50]
sub=['chemestry','physics','maths','computer','english']
pd.Series(data=marks,index=sub,name="Prashant 12th Marks")
# Out:
# chemestry    70
# physics      80
# maths        90
# computer     77
# english      50
# Name: Prashant 12th Marks, dtype: int64

# %%
d={'chemestry':70,'physics':80,'maths':90,'computer':77,'english':60}
s=pd.Series(d,name="My Marks")
s
# Out:
# chemestry    70
# physics      80
# maths        90
# computer     77
# english      60
# Name: My Marks, dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.size
# Out:
# 5

# %%
s.is_unique
# Out:
# True

# %%
s.index
# Out:
# Index(['chemestry', 'physics', 'maths', 'computer', 'english'], dtype='object')

# %%
s.values
# Out:
# array([70, 80, 90, 77, 60])

# %%
pd.read_csv(r'kohli_ipl.csv',index_col='match_no')['runs']
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movie=pd.read_csv(r"bollywood.csv",index_col='movie')['lead']

vk=pd.read_csv('kohli_ipl.csv',index_col='match_no')['runs']

sub=pd.read_csv('subs.csv')['Subscribers gained']

# %%
vk.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
vk.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movie.sample(5)
# Out:
# movie
# Tehzeeb (2003 film)      Shabana Azmi
# Andaaz                   Akshay Kumar
# Namastey London          Akshay Kumar
# Madaari                   Irrfan Khan
# Commando 3 (film)      Vidyut Jammwal
# Name: lead, dtype: object

# %%
movie.value_counts()
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %%
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
movie.sort_index(ascending=False)
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %%
vk.name
# Out:
# 'runs'

# %%
vk.unique()
# Out:
# array([  1,  23,  13,  12,   9,  34,   0,  21,   3,  10,  38,  11,  50,
#          2,  22,  19,  16,  15,  20,  24,   7,  17,  42,  58,  14,  37,
#         71,  35,  30,  56,  67,  27,  39,  31,  70,   8,   6,  57,   4,
#         18,  45,  36,  73,  51,  65,  32,  25,  93,  99,  49,  41,  62,
#         48,  82,  44,  75,  79,  33,  80, 100,  52, 108, 109, 113,  54,
#         28,  64,  55,   5,  92,  68,  46,  84,  29,  72,  43,  90,  53])

# %%
sub.count()
# Out:
# np.int64(365)

# %%
sub.shape
# Out:
# (365,)

# %%
marks=[70,80,90,77,np.nan]
subject=['chemestry','physics','maths','computer','english']
pd.Series(data=marks,index=subject).count()
# Out:
# np.int64(4)

# %%
sub.sum()
# Out:
# np.int64(49510)

# %%
sub.mean(),movie.mode().values[0],vk.std()
# Out:
# (np.float64(135.64383561643837), 'Akshay Kumar', np.float64(26.22980132830278))

# %%
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
vk.iloc[0]
# Out:
# np.int64(1)

# %%
movie[-1]
# Out:
# C:\Users\PRASHANT\AppData\Local\Temp\ipykernel_23516\988795955.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movie[-1]
# 'Akshay Kumar'

# %%
vk[::5].shape
# Out:
# (43,)

# %%
vk[[1,2,3,5]]
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 5     1
# Name: runs, dtype: int64

# %%
marks=[70,80,90,77,50]
sub=['chemestry','physics','maths','computer','english']
marks=pd.Series(data=marks,index=sub)

# %%
marks[0]=90
# Out:
# C:\Users\PRASHANT\AppData\Local\Temp\ipykernel_23516\956114599.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks[0]=90

# %%
marks
# Out:
# chemestry    90
# physics      80
# maths        90
# computer     77
# english      50
# dtype: int64

# %%
marks['scince']=100

# %%
marks
# Out:
# chemestry     90
# physics       80
# maths         90
# computer      77
# english       50
# scince       100
# dtype: int64

# %%
marks[2:4]=[95,80]

# %%
marks
# Out:
# chemestry     90
# physics       80
# maths         95
# computer      80
# english       50
# scince       100
# dtype: int64

# %%
len(vk)
# Out:
# 215

# %%
type(vk)
# Out:
# pandas.core.series.Series

# %%
dir(vk)[:5]
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES']

# %%
sorted(vk,reverse=True)[:5]
# Out:
# [113, 109, 108, 100, 100]

# %%
min(vk)
# Out:
# 0

# %%
max(vk)
# Out:
# 113

# %%
tuple(vk)[:5]
# Out:
# (1, 23, 13, 12, 1)

# %%
113 in vk.values
# Out:
# True

# %%
s=movie.value_counts()
s=s[s>20]
s
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
s.plot(kind='pie',autopct='%1.3f%%')
plt.title('Actor Worked On More Than 20 Movies')
plt.ylabel("")

plt.show()

# %%
# series built-in function

# %%
import sys
sys.getsizeof(vk)
# Out:
# 11768

# %%
vk=vk.astype('int32')

# %%
sys.getsizeof(vk)
# Out:
# 10908

# %%
vk[vk.between(50,100)].shape
# Out:
# (47,)

# %%
vk.clip(100,200).value_counts()
# Out:
# runs
# 100    212
# 108      1
# 109      1
# 113      1
# Name: count, dtype: int64

# %%
vk.drop_duplicates(keep='last').duplicated().sum()
# Out:
# np.int64(0)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
vk.drop_duplicates(keep='last',ignore_index=True)
# Out:
# 0      2
# 1     37
# 2     71
# 3     15
# 4     22
#       ..
# 73     0
# 74    20
# 75    73
# 76    25
# 77     7
# Name: runs, Length: 78, dtype: int32

# %%
s = pd.Series([10, np.nan, 30, None, 50])
s
# Out:
# 0    10.0
# 1     NaN
# 2    30.0
# 3     NaN
# 4    50.0
# dtype: float64

# %%
s.isna().sum()
# Out:
# np.int64(2)

# %%
s.size,s.count()
# Out:
# (5, np.int64(3))

# %%
s.dropna(ignore_index=True,inplace=False)
# Out:
# 0    10.0
# 1    30.0
# 2    50.0
# dtype: float64

# %%
s.fillna(method='bfill',limit=1)
# Out:
# C:\Users\PRASHANT\AppData\Local\Temp\ipykernel_23516\805054823.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s.fillna(method='bfill',limit=1)
# 0    10.0
# 1    30.0
# 2    30.0
# 3    50.0
# 4    50.0
# dtype: float64

# %%
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int32

# %%
movie.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int32

# %%
new=vk.head()
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int32

# %%
new[1]=100

# %%
vk
# Out:
# match_no
# 1      100
# 2       23
# 3       13
# 4       12
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int32

# %%
new=vk.head().copy()

# %%
new[1]=120

# %%
vk
# Out:
# match_no
# 1      100
# 2       23
# 3       13
# 4       12
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int32
