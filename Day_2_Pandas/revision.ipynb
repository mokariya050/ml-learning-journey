# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"E:\Datasets\credit_risk_dataset.csv")
data.shape
# Out:
# (32581, 12)

# %%
#series
dict={"name":"prashant","age":18,"enrollno":230130116038}
df=pd.Series(dict,index=["Name","Age","En"])
# Out:
# array([nan, nan, nan], dtype=object)

# %%
data.value_counts(subset=['person_home_ownership'])
# Out:
# person_home_ownership
# RENT                     16446
# MORTGAGE                 13444
# OWN                       2584
# OTHER                      107
# Name: count, dtype: int64

# %%
data.loc[data['person_age']>22,"person_home_ownership"]
# Out:
# 2        MORTGAGE
# 3            RENT
# 4            RENT
# 6            RENT
# 7            RENT
#            ...
# 32576    MORTGAGE
# 32577    MORTGAGE
# 32578        RENT
# 32579    MORTGAGE
# 32580        RENT
# Name: person_home_ownership, Length: 27704, dtype: object

# %%
data[data['person_home_ownership']=="RENT"].value_counts('person_home_ownership')
# Out:
# person_home_ownership
# RENT    16446
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
data.plot(y='person_income',x='loan_amnt',kind="scatter")
# Out:
# <Axes: xlabel='loan_amnt', ylabel='person_income'>

# %%
data['loan_intent'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='loan_intent'>

# %%
data.sort_values(by=['person_age'],ascending=False,ignore_index=True)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0             144         250000                  RENT                4.0
# 1             144         200000              MORTGAGE                4.0
# 2             144        6000000              MORTGAGE               12.0
# 3             123          80004                  RENT                2.0
# 4             123          78000                  RENT                7.0
# ...           ...            ...                   ...                ...
# 32576          20          64000                  RENT                3.0
# 32577          20          34800                  RENT                3.0
# 32578          20          42000                  RENT                4.0
# 32579          20          94000                  RENT                4.0
# 32580          20          32652              MORTGAGE                0.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
data.duplicated().index
# Out:
# RangeIndex(start=0, stop=32581, step=1)

# %%
data.drop_duplicates(ignore_index=True,keep="last")
# Out:
# (32416, 12)

# %%
# Out:
# (32581, 12)
