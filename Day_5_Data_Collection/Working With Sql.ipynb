# %%
import pandas as pd
import numpy as np

# %%
import mysql.connector as q

# %%
conn=q.connect(host='localhost',user='root',password='',database='inventory_db')

# %%
pd.read_sql("select * from users",conn,index_col='id',parse_dates=['created_at'])
# Out:
# C:\Users\PRASHANT\AppData\Local\Temp\ipykernel_17924\818334527.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select * from users",conn,index_col='id',parse_dates=['created_at'])
#              username                          email  \
# id
# 1               admin                admin@brand.com
# 6   mokariya.prashant  mokariyaprashant030@gmail.com
#
#                                         password_hash               name  \
# id
# 1   scrypt:32768:8:1$thv4DPRWdbnWJGBw$5431048b496e...               john
# 6   scrypt:32768:8:1$j7h1sWqQuqN0bOBU$adabf99afa5d...  mokariya prashant
#
#      role          address         city country phone  \
# id
# 1   admin  Sunset Blvd, 38  Los Angeles     USA  None
# 6   staff             None         None    None  None
#
# ...

# %%
# read documentation for more details
